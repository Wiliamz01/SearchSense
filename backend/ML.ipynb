# %% [markdown]
# # Part 2: EDA, Feature Engineering, and Model Development

# %% [markdown]
# ### Future Optimizations
#
# 1. Ignore website navigation for websites like (wikipedia, stackoverflow, etc.)
#
#
# ### Tasks
#
# 1. Research into transformer, BART model, to better understand model set up and how to get highest performance
# 2. Experiment with BART input (lemmatize/not, capitalization, etc.) to find best performance
# 3. Try to implement BART model with recursion as per the drawn diagram
# 4. Research into paralellization of transformer models with HuggingFace
#
# ### Notes
#
# 1. To actually make project work, we need to create a few metrics that we can train a DL model on. Maybe, linguistic complexity (formulaic), sentiment analysis, text length, etc.

# %%
#import import_ipynb
import WebScrape
# Out:
# [nltk_data] Downloading package punkt to C:\Users\William
# [nltk_data]     Zhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\William
# [nltk_data]     Zhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\William
# [nltk_data]     Zhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = WebScrape.get_df()
# Out:
# Scraping...:   0%|          | 0/1 [00:00<?, ?it/s]
# Error: Failed to retrieve content for: https://www.spiceworks.com/tech/artificial-intelligence/articles/what-is-ml/
# Exception: HTTPSConnectionPool(host='www.spiceworks.com', port=443): Max retries exceeded with url: /tech/artificial-intelligence/articles/what-is-ml/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001A08E4D1BA0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Scraping...: 100%|██████████| 1/1 [00:14<00:00, 14.20s/it]
# Grabbed search results
# 46
# 12813

# %%
df
# Out:
#                      Domain  \
# 0                 mathworks
# 1                    expert
# 2                       ibm
# 3                    oracle
# 4                microfocus
# 5             geeksforgeeks
# 6           mygreatlearning
# 7              en.wikipedia
# 8                techtarget
# 9                     zdnet
# 10             mitsloan.mit
# 11                      sas
# 12         technologyreview
# 13        developers.google
# 14             royalsociety
# 15              simplilearn
# 16               javatpoint
# 17          azure.microsoft
# 18                      hpe
# 19                brookings
# 20                   energy
# 21                   netapp
# 22                   energy
# 23             cloud.google
# 24               databricks
# 25                   nvidia
# 26                 coursera
# 27                    cisco
# 28                      sap
# 29                    eweek
# 30                   netapp
# 31                  builtin
# 32               aws.amazon
# 33                   levity
# 34              monkeylearn
# 35                      arm
# 36                     bbva
# 37                  zendesk
# 38                 fortinet
# 39                     domo
# 40              datarevenue
# 41   ischoolonline.berkeley
# 42                   talend
# 43               trendmicro
# 44            link.springer
# 45  ai.engineering.columbia
#
#                                                 Title  \
# 0   Artificial Intelligence (AI) vs. Machine Learning
# 1   Artificial Intelligence (AI) vs. Machine Learning
# 2   Artificial Intelligence (AI) vs. Machine Learning
# 3   Artificial Intelligence (AI) vs. Machine Learning
# 4   Artificial Intelligence (AI) vs. Machine Learning
# 5   Artificial Intelligence (AI) vs. Machine Learning
# 6   Artificial Intelligence (AI) vs. Machine Learning
# 7   Artificial Intelligence (AI) vs. Machine Learning
# 8   Artificial Intelligence (AI) vs. Machine Learning
# 9   Artificial Intelligence (AI) vs. Machine Learning
# 10  Artificial Intelligence (AI) vs. Machine Learning
# 11  Artificial Intelligence (AI) vs. Machine Learning
# 12  Artificial Intelligence (AI) vs. Machine Learning
# 13  Artificial Intelligence (AI) vs. Machine Learning
# 14  Artificial Intelligence (AI) vs. Machine Learning
# 15  Artificial Intelligence (AI) vs. Machine Learning
# 16  Artificial Intelligence (AI) vs. Machine Learning
# 17  Artificial Intelligence (AI) vs. Machine Learning
# 18  Artificial Intelligence (AI) vs. Machine Learning
# 19  Artificial Intelligence (AI) vs. Machine Learning
# 20  Artificial Intelligence (AI) vs. Machine Learning
# 21  Artificial Intelligence (AI) vs. Machine Learning
# 22  Artificial Intelligence (AI) vs. Machine Learning
# 23  Artificial Intelligence (AI) vs. Machine Learning
# 24  Artificial Intelligence (AI) vs. Machine Learning
# 25  Artificial Intelligence (AI) vs. Machine Learning
# 26  Artificial Intelligence (AI) vs. Machine Learning
# 27  Artificial Intelligence (AI) vs. Machine Learning
# 28  Artificial Intelligence (AI) vs. Machine Learning
# 29  Artificial Intelligence (AI) vs. Machine Learning
# 30  Artificial Intelligence (AI) vs. Machine Learning
# 31  Artificial Intelligence (AI) vs. Machine Learning
# 32  Artificial Intelligence (AI) vs. Machine Learning
# 33  Artificial Intelligence (AI) vs. Machine Learning
# 34  Artificial Intelligence (AI) vs. Machine Learning
# 35  Artificial Intelligence (AI) vs. Machine Learning
# 36  Artificial Intelligence (AI) vs. Machine Learning
# 37  Artificial Intelligence (AI) vs. Machine Learning
# 38  Artificial Intelligence (AI) vs. Machine Learning
# 39  Artificial Intelligence (AI) vs. Machine Learning
# 40  Artificial Intelligence (AI) vs. Machine Learning
# 41  Artificial Intelligence (AI) vs. Machine Learning
# 42  Artificial Intelligence (AI) vs. Machine Learning
# 43  Artificial Intelligence (AI) vs. Machine Learning
# 44  Artificial Intelligence (AI) vs. Machine Learning
# 45  Artificial Intelligence (AI) vs. Machine Learning
#
#                                                   URL  \
# 0   https://www.mathworks.com/discovery/machine-le...
# 1   https://www.expert.ai/blog/machine-learning-de...
# 2         https://www.ibm.com/topics/machine-learning
# 3   https://www.oracle.com/artificial-intelligence...
# 4   https://www.microfocus.com/en-us/what-is/machi...
# 5   https://www.geeksforgeeks.org/ml-machine-learn...
# 6   https://www.mygreatlearning.com/blog/what-is-m...
# 7      https://en.wikipedia.org/wiki/Machine_learning
# 8   https://www.techtarget.com/searchenterpriseai/...
# 9   https://www.zdnet.com/article/what-is-machine-...
# 10  https://mitsloan.mit.edu/ideas-made-to-matter/...
# 11  https://www.sas.com/en_us/insights/analytics/m...
# 12  https://www.technologyreview.com/2018/11/17/10...
# 13  https://developers.google.com/machine-learning...
# 14  https://royalsociety.org/topics-policy/project...
# 15  https://www.simplilearn.com/tutorials/machine-...
# 16        https://www.javatpoint.com/machine-learning
# 17  https://azure.microsoft.com/en-us/resources/cl...
# 18  https://www.hpe.com/br/en/what-is/machine-lear...
# 19  https://www.brookings.edu/articles/what-is-mac...
# 20  https://www.energy.gov/science/doe-explainsmac...
# 21  https://www.netapp.com/artificial-intelligence...
# 22  https://www.energy.gov/science/doe-explainsmac...
# 23  https://cloud.google.com/learn/what-is-machine...
# 24  https://www.databricks.com/glossary/machine-le...
# 25  https://www.nvidia.com/en-us/glossary/data-sci...
# 26    https://www.coursera.org/learn/machine-learning
# 27  https://www.cisco.com/c/en/us/products/securit...
# 28  https://www.sap.com/products/artificial-intell...
# 29  https://www.eweek.com/big-data-and-analytics/m...
# 30  https://www.netapp.com/artificial-intelligence...
# 31               https://builtin.com/machine-learning
# 32   https://aws.amazon.com/what-is/machine-learning/
# 33  https://levity.ai/blog/difference-machine-lear...
# 34          https://monkeylearn.com/machine-learning/
# 35  https://www.arm.com/glossary/machine-learning-...
# 36  https://www.bbva.com/en/innovation/machine-lea...
# 37  https://www.zendesk.com/blog/machine-learning-...
# 38  https://www.fortinet.com/resources/cyberglossa...
# 39  https://www.domo.com/glossary/what-are-machine...
# 40  https://www.datarevenue.com/en-blog/what-is-ma...
# 41  https://ischoolonline.berkeley.edu/blog/what-i...
# 42  https://www.talend.com/resources/what-is-machi...
# 43  https://www.trendmicro.com/vinfo/us/security/d...
# 44  https://link.springer.com/chapter/10.1007/978-...
# 45  https://ai.engineering.columbia.edu/ai-vs-mach...
#
#                                                  Text
# 0   What is Machine Learning? | How it Works, Tuto...
# 1   What Is the Definition of Machine Learning? | ...
# 2   What is Machine Learning? | IBM What is machin...
# 3   What is Machine Learning? | Oracle Accessibili...
# 4   What Is Machine Learning and Why Is It Importa...
# 5   What is Machine Learning? - GeeksforGeeks  to ...
# 6   What is Machine Learning? Definition, Types, A...
# 7   Machine learning - Wikipedia Jump to      move...
# 8   What Is Machine Learning and Why Is It Importa...
# 9   What is machine learning? Everything you need ...
# 10  Machine learning, explained | MIT Sloan  to   ...
# 11  Machine Learning: What it is and why it matter...
# 12  What is machine learning? | MIT Technology Rev...
# 13  Machine Learning |  for Developers Machine Lea...
# 14  What is machine learning? | Royal Society Can ...
# 15  What Is Machine Learning and Types of Machine ...
# 16  Machine Learning: What It is, Tutorial, Defini...
# 17  Artificial Intelligence vs. Machine Learning |...
# 18  What is Machine Learning? | Glossary | HPE Bra...
# 19  What is machine learning? | Brookings Experts ...
# 20  DOE Explains...Machine Learning | Department o...
# 21  What Is Machine Learning - ML - and Why Is It ...
# 22  DOE Explains...Machine Learning | Department o...
# 23  What is Machine Learning? |  Cloud Overview cl...
# 24  What are Machine Learning Models?PlatformThe D...
# 25  Machine Learning – What Is It and Why Does It ...
# 26  Supervised Machine Learning: Regression and Cl...
# 27  What Is Machine Learning in Security? - Cisco ...
# 28  What is machine learning? | Definition, types,...
# 29  What Is Machine Learning? | eWEEK Close Latest...
# 30  What Is Machine Learning - ML - and Why Is It ...
# 31  What Is Machine Learning: Definition and Examp...
# 32  What is Machine Learning? - Enterprise Machine...
# 33  Deep Learning vs. Machine Learning – What’s Th...
# 34  An Introduction to Machine LearningTry MonkeyL...
# 35  What Are Machine Learning Algorithms? – Arm®  ...
# 36  'Machine learning': ¿qué es y cómo funciona? C...
# 37  Deep learning vs. machine learning: What’s the...
# 38  What is Machine Learning? Definition, Types an...
# 39  The Basic Concepts of Machine Learning | Domo ...
# 40  What Is Machine Learning? – Visual Explanation...
# 41  What Is Machine Learning (ML)? - I School Onli...
# 42  What is Machine Learning? | TalendTalend logoM...
# 43  Machine Learning - Definition Business search ...
# 44  What Is Machine Learning? | SpringerLink  to  ...
# 45  Artificial Intelligence (AI) vs. Machine Learn...

# %%
import torch
from sklearn.model_selection import train_test_split

# Assuming you have a DataFrame called 'df' containing your data
# Split the data into train and test sets (80% train, 20% test)
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Split the train data further into train and validation sets (80% train, 20% validation)
train_data, val_data = train_test_split(train_data, test_size=0.2, random_state=42)

# Print the sizes of each dataset
print("Train set size:", len(train_data))
print("Validation set size:", len(val_data))
print("Test set size:", len(test_data))

# %%
test_data.reset_index().drop(["index"], axis = 1)
val_data.reset_index().drop(["index"], axis = 1)
train_data.reset_index().drop(["index"], axis = 1)

# %%
df.head()
# Out:
#           Domain                    Title  \
# 0      mathworks  Python Machine Learning
# 1            ibm  Python Machine Learning
# 2         oracle  Python Machine Learning
# 3     techtarget  Python Machine Learning
# 4  geeksforgeeks  Python Machine Learning
#
#                                                  URL  \
# 0  https://www.mathworks.com/discovery/machine-le...
# 1        https://www.ibm.com/topics/machine-learning
# 2  https://www.oracle.com/artificial-intelligence...
# 3  https://www.techtarget.com/searchenterpriseai/...
# 4  https://www.geeksforgeeks.org/ml-machine-learn...
#
#                                                 Text
# 0  What is Machine Learning? | How it Works, Tuto...
# 1  What is Machine Learning? | IBM What is machin...
# 2  What is Machine Learning? | Oracle Accessibili...
# 3  What Is Machine Learning and Why Is It Importa...
# 4  What is Machine Learning? - GeeksforGeeks Skip...

# %%
df["URL"][0]
# df["Text"][0]
# Out:
# 'https://www.guru99.com/what-is-software-engineering.html'

# %%
from transformers import pipeline

summarizer = pipeline("summarization", 
                      model="pszemraj/led-base-book-summary", 
                      device=0 if torch.cuda.is_available() else -1,
                      )

result = summarizer(
    df["Text"][0],
    min_length=8,
    max_length=256,
    no_repeat_ngram_size=3,
    encoder_no_repeat_ngram_size=3,
    repetition_penalty=3.5,
    num_beams=4,
    do_sample=False,
    early_stopping=True,
)
print(df["Text"][0])
print()
print(result[0]["summary_text"])
# Out:
# What is Software Engineering? Definition, Basics, Characteristics  to  Home TestingExpand Agile Testing JUnit Quality Center(ALM) Bugzilla HP Loadrunner RPA Cucumber Software Testing SAP Testing Database Testing Mobile Testing Selenium ETL Testing Mantis SoapUI JMeter Postman TEST Management JIRA QTP TestLink SAPExpand ABAP CRM PI/PO APO Crystal Reports PP Beginners FICO SD Basis HANA SAPUI5 BODS HR Security Tutorial BI/BW  Solution Manager BPC QM Successfactors CO Payroll SAP  WebExpand Apache Java PHP SQL Server AngularJS JSP PL/SQL UML ASP.NET Kotlin PostgreSQL VB.NET  Linux Python VBScript # MariaDB ReactJS Web Services ++ MS Access Ruby & Rails WPF CodeIgniter MySQL Scala SQLite DBMS Node.js SQL Perl JavaScript Must LearnExpand Accounting Embedded Systems Operating System Algorithms Ethical Hacking PMP Android Excel Tutorial Photoshop Blockchain Go Programming Project Management Business Analyst IoT Reviews Build Website ITIL Salesforce Cloud Computing Jenkins SEO COBOL MIS Software Engineering Compiler Design Movie VBA  Networking VPN Big DataExpand AWS Hive Power BI Big Data Informatica Qlikview Cassandra MicroStrategy Tableau Cognos MongoDB Talend Data Warehousing NiFi ZooKeeper DevOps OBIEE Pentaho HBase Live ProjectExpand Live Agile Testing Live Selenium Project Live HP ALM Live Selenium 2 Live Java Project Live Security Testing Live Mobile Testing Live Testing Project Live Payment Gateway Live Testing 2 Live PHP Project Live Telecom Live Projects Hub Live UFT/QTP Testing Live Python Project Live SEO Project AIExpand Artificial Intelligence PyTorch Data Science R Programming Keras TensorFlow NLTK Search Toggle  What is Software Engineering? Definition, Basics, Characteristics ByMatthew Martin Hours UpdatedJune 10, 2023 What is Software Engineering? Software engineering is defined as a process of analyzing  requirements and then designing, building, and testing software application which will satisfy those requirements. Let’s look at the various definitions of software engineering: IEEE, in its standard 610.12-1990, defines software engineering as the application of a systematic, disciplined, which is a computable approach for the development, operation, and maintenance of software. Fritz Bauer defined it as ‘the establishment and used standard engineering principles. It helps you to obtain, economically, software which is reliable and works efficiently on the real machines’. Boehm defines software engineering, which involves, ‘the practical application of scientific knowledge to the creative design and building of computer programs. It also includes associated documentation needed for developing, operating, and maintaining them.’ In this software engineering tutorial, you will learn: What is Software Engineering? Why Software Engineering? Software Crisis & its Solution Why Software Engineering is Popular? Relationship of Software Engineering with Other Disciplines Challenges of Software Engineering Attributes for Software Products Characteristics of Good Software Why Software Engineering? Software Crisis & its Solution: What was the Software Crisis? It was in the late 1960s when many software projects failed. Many software became over budget. Output was an unreliable software which is expensive to maintain. Larger software was difficult and quite expensive to maintain. Lots of software not able to satisfy the growing requirements of the customer. Complexities of software projects increased whenever its hardware capability increased. Demand for new software increased faster compared with the ability to generate new software. All the above issues lead to ‘Software Crisis.’ The Solution Solution was to the problem was transforming unorganized coding effort into a software engineering discipline. These engineering models helped companies to streamline operations and deliver software meeting customer requirements. The late 1970s saw the widespread uses of software engineering principles. In the 1980s saw the automation of ...
#
# Next, Martin updates the definition of Software engineering with additional information in order to better understand the challenges facing software engineers. He explains that "software engineering" consists of three basic principles: first, a technical overview; second, a descriptive description of what it is like to be a software engineer; and third, a detailed assessment of the capabilities of a particular product or service. Martin then provides an introduction to the concept of Software Crisis, which he calls "Software Crisis & Solution." Martin describes the early 1960s as a time when many large-scale, often expensive, software development was common. This crisis was caused by several factors: high cost, availability, complexity, and/or maintenance. These factors led to the 'Software Crisis'. Martin also discusses the importance of "operational transitional maintenance," i.e., the establishment and use of standard engineering techniques. In this tutorial, Martin introduces the concepts of "Software Engineering" and "Why Software Engineering" throughout the course of the 2023-2023 study period.

# %% [markdown]
# # NOTES ABOUT SUMMARIZATION
# 1. We need to filter out the navigation content for Bart to do a good job, I assume we can accomplish that through briefly studying the html of some of the web pages
# 2. Some website includes latex to describe mathematical expressions or other such expressions, hence BART cannot read that and cannot comprehend that, we either need to integrate a latex parser or filter out those expressions
# 3. Research why LED keeps cutting off some of the summary, how to fix this
