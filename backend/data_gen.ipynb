# %%
queries = ['What is STEM education?', 'What is photosynthesis?', 'How does the water cycle work?', 'How does DNA replication occur?', 'What are the applications of quantum physics?', 'What is the role of white blood cells?', 'What is the theory of relativity?', 'What are genetic mutations?', 'What is the Pythagorean theorem?', 'How to solve quadratic equations?', "What is Heron's formula?", 'How to calculate standard deviation?', 'What is the Big Bang theory?', "What is Newton's law of motion?", 'How to solve for the inverse of matrices?', 'What is machine learning?', 'What is cloud computing?', 'How does artificial intelligence work?', 'How does a circuit work?', 'What are renewable energy sources?', 'What is the theory of evolution?', 'How does the internet work?', 'What is climate change?', 'How to solve differential equations?', 'What is the Doppler effect?', 'What is protein synthesis?', 'How does a combustion engine work?', 'What is nanotechnology?', 'How does a 3D printer work?', 'What is genetic engineering?', 'How does nuclear fusion work?', 'What is the periodic table of elements?', 'What is the Heisenberg uncertainty principle?', 'How does photosynthesis work?', 'What are trigonometric functions?', 'How do computer algorithms work?', 'What is the role of a catalyst in a chemical reaction?', 'How does blockchain technology work?', "What is Einstein's theory of general relativity?", 'How does radioactivity work?', 'What is the Fibonacci sequence?', 'What are black holes?', 'What is the human genome project?', 'What is the Krebs cycle?', 'How does a telescope work?', 'What is the law of thermodynamics?', 'What is the Schroedinger equation?', 'How does neural network work?', 'What is gravitational wave?', 'How does a jet engine work?', 'What is the principle of superposition in quantum mechanics?', 'How do vaccines work?', 'What is cybersecurity?', 'What is the role of enzymes in digestion?', 'What is the Internet of Things (IoT)?', 'How does Wi-Fi work?', 'What is the Turing machine?', 'What are stem cells?', "What is Green's theorem in mathematics?", 'How does a solar panel work?', 'What is Bayes theorem in probability?', 'What are the applications of calculus in engineering?', 'How does a transformer work in electrical engineering?', 'What is quantum entanglement in physics?', 'How does data encryption work?', 'What is the principle of conservation of energy?', "What is Pascal's triangle in mathematics?", 'How does cellular respiration work?', "What is the Hubble's law in astrophysics?", 'What are the applications of AI in healthcare?', 'How does a lithium-ion battery work?', 'What is the role of gut microbiome in human health?', "What is the Bernoulli's equation in fluid dynamics?", 'What is Fourier transform in signal processing?', 'How does a radar work?', 'What is the Second law of thermodynamics?', 'How does the immune system fight viruses?', 'What are quarks in particle physics?', 'How does GPS technology work?', "What is the Zeno's paradox in philosophy of mathematics?", 'What is Big O notation in computer science?', 'How does a rocket engine work?', 'What is epigenetics?', 'What are the principles of sustainable development?', 'How does a nuclear reactor work?', 'What is the central dogma of molecular biology?', 'What is the Drake equation in the search for extraterrestrial life?', 'What is the Golden ratio in mathematics?', 'How does a wind turbine work?', "What is Gauss's Law in electrostatics?", 'How do magnetic fields interact in physics?', 'What is the role of leptons in particle physics?', 'What is the difference between classical and quantum mechanics?', 'How do neurons communicate in the nervous system?', "What is Euler's formula in complex analysis?", 'How does chromatography work in chemistry?', "What is Mendel's Law in genetics?", 'How does gene editing work?', 'What are the principles of aerodynamics?', 'How does a hydraulic system work?', 'What are dark matter and dark energy in cosmology?', 'What is the function of the endocrine system in the human body?', 'How does Bluetooth technology work?', 'What is the significance of prime numbers in cryptography?', 'What are the laws of Boolean algebra in digital electronics?', 'How does a fuel cell work?', 'What is the RNA world hypothesis?', 'What is the difference between anaerobic and aerobic respiration?', 'What are transposons in genetics?', "What is Laplace's equation in mathematical physics?", 'How does a transistor work?', 'What is virtual reality technology?', 'What are the applications of linear algebra in computer graphics?', 'How do self-driving cars work?', 'What is the Twin Paradox in special relativity?', 'What are fractals in mathematics?', "What is Planck's constant in quantum physics?", 'How does CRISPR gene editing work?', 'What is Riemann Hypothesis in number theory?', 'How does the process of fertilization occur in plants?', 'What are bosons in particle physics?', 'What is the role of neurotransmitters in the brain?', 'How does an electric car work?', 'What is the meaning of entropy in thermodynamics?', 'What is the concept of singularity in black holes?', 'How does a geothermal power plant work?', 'What is the Navier-Stokes equation in fluid dynamics?', 'How does light behave in fiber optics?', "What is the Kepler's laws of planetary motion?", 'What is the role of the xylem and phloem in plants?', 'How do algorithms work in search engines?', 'What is the significance of the Higgs boson particle?', 'What is the function of vitamins in the human body?', 'How does the Fourier series work in signal analysis?', 'What is the application of matrix multiplication in computer graphics?', 'What are the laws of robotics?', 'How does a nuclear magnetic resonance (NMR) spectrometer work?', 'What is the function of dark matter in the universe?', 'What is the principle of superconductivity?', 'What is the Turing test in artificial intelligence?', 'How does a fusion reactor work?', 'What is the Lorenz attractor in chaos theory?', 'What is the function of telomeres in DNA replication?', 'How does a particle accelerator work?', 'What is the Fibonacci sequence in nature?', 'What is the meaning of wave-particle duality in quantum mechanics?', 'What is the difference between prokaryotic and eukaryotic cells?', 'How does an alternating current (AC) motor work?', 'What is P vs NP problem in computer science?', 'What are neutrinos in particle physics?', 'What is the role of myelin sheath in the nervous system?', 'How does photosynthesis contribute to the carbon cycle?', "What is Archimedes' principle in fluid mechanics?", 'What is quantum tunneling?', "How do plate tectonics shape the Earth's crust?", 'What are the properties of a superconductor?', "What is Lenz's law in electromagnetism?", 'What is bioinformatics in genomics research?', 'How does a microbial fuel cell work?', 'What are topological phases of matter?', 'What is the role of ATP in energy transfer?', 'What is space-time curvature in general relativity?', 'What are the steps of the scientific method?', 'What is the function of insulin in the human body?', 'How does an induction cooker work?', 'What is swarm intelligence in AI?', 'What is genetic drift in evolution?', 'What are the applications of graphene?', 'How do satellites maintain their orbit?', 'What is the concept of biodiversity?', 'What are the basics of computational fluid dynamics?', 'What is the theory of plate tectonics?', 'How does a cyclotron work in particle physics?', 'What are the laws of planetary motion?', 'What is the function of the lymphatic system in the human body?', 'What is the role of artificial neural networks in deep learning?', 'What is the concept of redshift and blueshift in astrophysics?', 'How does radioactive decay occur in nuclear physics?', 'What is the limit in calculus?', 'What is the role of chlorophyll in photosynthesis?', 'What are the types of chemical bonds?', 'What are the basics of quantum computing?', 'How does a hydroelectric power plant work?', 'What is the structure of a eukaryotic cell?', "What is the Bell's theorem in quantum mechanics?", 'What is the process of DNA transcription and translation?', 'How does a gas turbine engine work?', 'What are the basic principles of hydraulics?', 'What is the law of reflection and refraction?', 'How do semiconductors work in electronics?', 'What is the function of the circulatory system in the human body?', 'What is the role of the CPU in a computer?', 'What are Cepheid variables in astronomy?', 'What is the principle of interferometry?', 'What are exoplanets and how are they discovered?', "What is Le Chatelier's principle in chemistry?", 'What is the function of the endoplasmic reticulum in a cell?', 'How does a bioreactor work in biotechnology?', 'What is the law of conservation of angular momentum?', 'What is an allele in genetics?', 'What is a Turing machine in theoretical computer science?', 'How does a photovoltaic cell work?', 'What are the fundamentals of object-oriented programming?', 'What is the theory of elasticity in physics?', 'What is the process of nitrogen fixation in ecology?', 'What is protein folding and why is it important?', "What is Avogadro's number in chemistry?", 'How does sonar work in underwater communication?', "What is Fermat's Last Theorem in number theory?", 'What is the function of the Golgi apparatus in a cell?', 'What is gravitational lensing in astrophysics?', 'What are the applications of augmented reality technology?', 'How does a fuel injection system work in an automobile?', 'What is the Pauli exclusion principle in quantum physics?', 'How does the process of meiosis contribute to genetic diversity?', 'What is the role of polymers in material science?', 'What are the principles of geology?', 'What is a supermassive black hole?', 'How does an air conditioner work?', 'What is the function of the pituitary gland in the endocrine system?', 'What are the principles of organic chemistry?', 'What is eigenvalue and eigenvector in linear algebra?', 'What are the applications of differential equations in real life?', 'How does an atomic clock work?', 'What is the law of conservation of momentum in physics?', 'What are exosomes in cell biology?', 'What is the principle of least action in classical mechanics?', 'How does laser cooling work in quantum physics?', 'What is the Boltzmann constant in thermodynamics?', 'How does an electron microscope work?', 'What is the Human Microbiome Project in biology?', 'What is the difference between analog and digital signals in electronics?', 'What is the principle of buoyancy in fluid mechanics?', 'What is a Turing-complete language in computer science?', "What is Ohm's law in electrical engineering?", 'How does a scanning tunneling microscope work?', 'What are the principles of metallurgy?', 'What is DNA replication in molecular biology?', 'What is the concept of wave function in quantum physics?', 'How do enzymes catalyze biochemical reactions?', "What is Carnot's theorem in thermodynamics?", 'What is the structure and function of mitochondria in a cell?', 'How does carbon dating work in archaeology?', 'What is an isotope in chemistry?', 'What is the process of evaporation and condensation in physics?', 'What are eigenvalues in quantum mechanics?', "What is the purpose of the ozone layer in the earth's atmosphere?", 'How does a hydraulic brake system work?', "What is Kirchhoff's law in electrical circuits?", 'What is the function of the pancreas in the human body?', 'What is the principle of operation of a gas chromatograph?', 'What is the Nash equilibrium in game theory?', 'How does Wi-Fi technology work?', 'What is the process of distillation in chemistry?', 'What is the principle of photovoltaics?', 'What is a semiconductor diode in electronics?', 'What is the concept of stoichiometry in chemistry?', 'How does a steam engine work?', 'What are prions in biology?', 'What is a parsec in astronomy?', 'What are the principles of aerodynamics in aircraft design?', 'What is the process of mitosis in cell division?', 'What is the Boltzmann distribution in statistical mechanics?', "What is Bernoulli's principle in fluid dynamics?", 'How do binary search trees work in computer science?', 'What is the phenomenon of diffraction in wave optics?', 'What is the significance of stem cells in biology?', 'How does an electric generator work?', "What is Coulomb's Law in electrostatics?", 'What is the concept of genetic linkage in genetics?', 'How does a solar thermal plant work?', "What is Schrodinger's cat in quantum mechanics?", 'What is the function of ribosomes in protein synthesis?', 'What are hydrocarbons in organic chemistry?', 'How does a digital camera work?', 'What is the role of plastids in plants?', "What is Newton's law of cooling?", 'What is a pointer in C++?', 'What are lichens in botany?', 'How does an accelerometer work in physics?', 'What are the principles of sonography in medical diagnostics?', 'What is Hardy-Weinberg equilibrium in population genetics?', 'How does a dynamo generate electricity?', 'What is the role of auxins in plant growth?', 'What is the significance of the Turing Machine in computer science?', 'What are Hadrons in particle physics?', 'What is the greenhouse effect and its impact on global warming?', 'What is the function of the hypothalamus in the human body?', 'How does nuclear fusion work in the sun?', 'What is a quantum leap in quantum physics?']

# %%
#imports
import requests #send HTTP requests to web pages and retrieve their content
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from urllib.parse import urlparse, urljoin
import pandas as pd
from nltk.corpus import stopwords
import http.client
import re
import csv
from zenrows import ZenRowsClient

nltk.download('punkt')
#remove filler words from an example column
nltk.download("stopwords")
nltk.download('wordnet')



import concurrent.futures
from tqdm import tqdm
#Working implementation

client = ZenRowsClient("6239d8fe168c1e2242a4bddd54b0a0813090b31a")
params_reg = {"js_render":"true","antibot":"true"}
params_google = {"premium_proxy":"true"}

def gen_data(query_list):    
    df_list = []
    #Remove <a> tags from search results 7/19/23
    # session = requests.Session()
    # retry = Retry(connect=2, backoff_factor=0.5)
    # adapter = HTTPAdapter(max_retries=retry)
    # session.mount('http://', adapter)
    # session.mount('https://', adapter)
    

    # Define the search query and retrieve search results
    search_query = query_list
    search_engine_url = "https://www.google.com/search?q="
    
    # Set headers to mimic a browser request
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    
    # Number of search result pages to retrieve (each page typically has 10 results)
    num_pages = 5
    
    def get_response(url):
        try:
            response = client.get(url, params=params_reg)
            result_soup = BeautifulSoup(response.content, "html.parser")
    
            
            # Remove <a> tags and their content from the parsed HTML content
            for a_tag in result_soup.find_all("a"):
                # Check if a <b> tag exists before or after the <a> tag
                if a_tag.find_previous_sibling("b") or a_tag.find_next_sibling("b"):
                    continue  # Keep the <a> tag and its content
                else:
                    a_tag.decompose()  # Remove the <a> tag and its content
    
                
            # Get the clean text without <a> tags
            text = result_soup.get_text()
            text = ' '.join(text.split())
            df_results = pd.DataFrame({"Title": [title], "URL": [url], "Text": [text]})
            df_list.append(df_results)
        except http.client.IncompleteRead:
            # print("Error: Incomplete read for:", url)
            return None
        except Exception as e:
            # print("Error: Failed to retrieve content for:", url)
            # print("Exception:", e)
            return None
    def preprocess(text, q):
        '''
        Input a text block and filter out unneeded characters
        Returns a filtered text block in the form of a string
        Function keeps punctuation, capitalization, stopwords, and special characters;
        removes LaTeX, keeps plain English, and strips beginning and end text
        '''
        # Remove LaTeX expressions
        cleaned_text = re.sub(r"\$.*?\$", "", text)
    
        stop_words = set(stopwords.words("english"))
        query_words = q.split()
        non_stop_word = next((word for word in query_words if word.lower() not in stop_words), None)
    
        # Strip beginning text
        text_words = cleaned_text.split()
    
        count = 0
        start_index = 0
        end_index = len(text_words)
        for i, word in enumerate(text_words):
            if word.lower() == non_stop_word.lower():
                count += 1
                if count == 3:
                    start_index = i
                    break
    
         # Strip ending text
            count = 0
            
            for i in range(len(text_words) - 1, -1, -1):
                if text_words[i].lower() == non_stop_word.lower():
                    count += 1
                    if count == 3:
                        end_index = i + 1
                        break
    
        # Hardcoding common navigation words in scraped text
        pattern = r"\b(?:skip|main|content|table|menu|displayclass|pagesubpageproperty|ad|copyright|com|ssc|f|wiki|courses|course|sign|up|log|facebook|google|email|forgot|password|user|existing|manually|already|account|f|frac|cdots|hspace|mm|ikamusumefan|gif|org|https|loading|align|p|x|c|extensionprocessorqueryprovider|libretexts|pageindex|dfrac|mathrm|newcommand|norm|extensionprocessorqueryprovider|pagesubpageproperty|browser|firefox|install|chrome|edge|wikimedia|commonswikibookswikiquotewikiversity|t)\b"
        cleaned_text = re.sub(pattern, "", cleaned_text, flags=re.IGNORECASE)
        cleaned_text = " ".join(text_words[start_index:end_index])
        
    
        return cleaned_text

    df_list_query = []
   
    for query in search_query:
        df_list = []
        print(f"searching: {query}") 
        all_urls = []
        for page in range(num_pages):
            # Calculate the start index for the current page
            start_index = page * 10
        
            try:
                # Make a GET request to retrieve the search result page
                response = client.get(search_engine_url + query + f"&start={start_index}", params=params_google)
                response.raise_for_status()  # Raise an exception for non-2xx status codes
        
            except requests.exceptions.RequestException as e:
                print("Error occurred for page", page+1)
                print("Exception:", e)
                continue
        
            # Parse and extract information from the search result page
            soup = BeautifulSoup(response.content, "html.parser")
            for result in soup.select("div.g"):
                title_element = result.select_one("h3")
                if title_element:
                    title = title_element.get_text()
                    url_element = result.find("a")
                    if url_element:
                        url = url_element["href"]
                        parsed_url = urlparse(url)
                        if parsed_url.scheme == "":
                            # Relative URL, convert it to absolute URL
                            base_url = response.url
                            url = urljoin(base_url, url)
                        all_urls.append(url)
        print(len(all_urls))
    
            
        executor = concurrent.futures.ThreadPoolExecutor(max_workers=10)
        
        for cur_url in all_urls:
            futures = [
                executor.submit(
                    get_response,
                    cur_url
                )
            ]
        
        
        results = []
        with tqdm(total=len(futures), desc="Scraping...") as pbar:
            for future in concurrent.futures.as_completed(futures):
                result = future.result()
                results.append(results)
                pbar.update(1)
                print(results)
        

        df_concatenated = pd.concat(df_list)
        print("Processing search results...")
        tld_pattern = re.compile(r'\.[a-zA-Z]+$')
        df_concatenated['Domain'] = df_concatenated['URL'].apply(lambda url: re.sub(tld_pattern, '', urlparse(url).netloc.replace("www.", "")))
        df_concatenated.insert(0, 'Domain', df_concatenated.pop('Domain'))
    
        df_concatenated["Text"] = df_concatenated["Text"].apply(lambda x: " ".join(x) if isinstance(x, list) else x)
        df_concatenated["Text"] = df_concatenated["Text"].apply(preprocess, q=query)

        df_concatenated = df_concatenated[df_concatenated["Text"].notna()]
        
        # Append the processed DataFrame for the current query to the list
        df_list_query.append(df_concatenated)
    # Process the search results as desired        
    # Extract domain names from URLs and set as the index for the dataframe

    df = pd.concat(df_list_query)

    return df
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zwill\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zwill\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\zwill\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !pip install zenrows
# Out:
# Collecting zenrows
#   Downloading zenrows-1.3.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenrows) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->zenrows) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->zenrows) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->zenrows) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->zenrows) (2023.5.7)
# Installing collected packages: zenrows
# Successfully installed zenrows-1.3.1

# %%
df = gen_data(queries)
# Out:
# searching: What is STEM education?
# 48
# Scraping...:   0%|                                        | 0/1 [00:00<?, ?it/s]/var/folders/_w/hcnc2bbx46qb52cr07g3sykh0000gn/T/ipykernel_6197/3640164101.py:58: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   result_soup = BeautifulSoup(response.content, "html.parser")
# Scraping...: 100%|████████████████████████████████| 1/1 [00:40<00:00, 40.65s/it]
# [[...]]
# Processing search results...
# searching: What is photosynthesis?
# 50
# Scraping...:   0%|                                        | 0/1 [00:00<?, ?it/s]/var/folders/_w/hcnc2bbx46qb52cr07g3sykh0000gn/T/ipykernel_6197/3640164101.py:58: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   result_soup = BeautifulSoup(response.content, "html.parser")
# Scraping...: 100%|████████████████████████████████| 1/1 [00:44<00:00, 44.09s/it]
# [[...]]
# Processing search results...
# searching: How does the water cycle work?
# 51
# Scraping...:   0%|                                        | 0/1 [00:00<?, ?it/s]/var/folders/_w/hcnc2bbx46qb52cr07g3sykh0000gn/T/ipykernel_6197/3640164101.py:58: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   result_soup = BeautifulSoup(response.content, "html.parser")
# Scraping...: 100%|████████████████████████████████| 1/1 [00:37<00:00, 37.29s/it]
# [[...]]
# Processing search results...
# /var/folders/_w/hcnc2bbx46qb52cr07g3sykh0000gn/T/ipykernel_6197/3640164101.py:58: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   result_soup = BeautifulSoup(response.content, "html.parser")
# searching: How does DNA replication occur?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = gen_data(queries)
#
# Cell In[1], line 139, in gen_data(query_list)
#     135 start_index = page * 10
#     137 try:
#     138     # Make a GET request to retrieve the search result page
# --> 139     response = client.get(search_engine_url + query + f"&start={start_index}", params=params_google)
#     140     response.raise_for_status()  # Raise an exception for non-2xx status codes
#     142 except requests.exceptions.RequestException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/zenrows/client.py:34, in ZenRowsClient.get(self, url, params, headers, **kwargs)
#      31 def get(
#      32     self, url: str, params: dict = None, headers: dict = None, **kwargs
#      33 ) -> requests.Response:
# ---> 34     return self._worker("GET", url, params, headers, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/zenrows/client.py:74, in ZenRowsClient._worker(self, method, url, params, headers, data, **kwargs)
#      70     headers = {}
#      72 final_headers.update(headers)
# ---> 74 return self.requests_session.request(
#      75     method, self.api_url, params=final_params, headers=final_headers, data=data, **kwargs
#      76 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("./content_data.csv")

# %%
print(df)
# Out:
#        Unnamed: 0          Domain  \
# 0               0   geeksforgeeks
# 1               0        gyandhan
# 2               0          invent
# 3               0    en.wikipedia
# 4               0  blog.teachmint
# ...           ...             ...
# 13386           0              dw
# 13387           0     phrases.org
# 13388           0        edcrocks
# 13389           0      sarahscoop
# 13390           0             gpb
#
#                                                  Title  \
# 0      What Does STEM Stand for in Education & School?
# 1      What Does STEM Stand for in Education & School?
# 2      What Does STEM Stand for in Education & School?
# 3      What Does STEM Stand for in Education & School?
# 4      What Does STEM Stand for in Education & School?
# ...                                                ...
# 13386              What Happens During a Quantum Jump?
# 13387              What Happens During a Quantum Jump?
# 13388              What Happens During a Quantum Jump?
# 13389              What Happens During a Quantum Jump?
# 13390              What Happens During a Quantum Jump?
#
#                                                      URL  \
# 0      https://www.geeksforgeeks.org/what-is-stem-edu...
# 1      https://www.gyandhan.com/blogs/stem-education-...
# 2      https://www.invent.org/blog/trends-stem/value-...
# 3      https://en.wikipedia.org/wiki/Science,_technol...
# 4             https://blog.teachmint.com/stem-education/
# ...                                                  ...
# 13386  https://www.dw.com/en/chinas-quantum-leap-made...
# 13387  https://www.phrases.org.uk/meanings/quantum-le...
# 13388  https://edcrocks.com/2023/03/22/the-quantum-le...
# 13389  https://sarahscoop.com/quantum-jumping-manifes...
# 13390  https://www.gpb.org/television/show/pbs-space-...
#
#                                                     Text
# 0      What is STEM Education and Why is it Important...
# 1      STEM Education System: A Complete Guide | Gyan...
# 2      The Benefits of STEM Education for Children Si...
# 3      Science, technology, engineering, and mathemat...
# 4      What is STEM Education? All You Need to Know |...
# ...                                                  ...
# 13386  China's quantum leap — Made in Germany – DW – ...
# 13387  The saying 'Quantum leap' - meaning and origin...
# 13388  {"code":"RESP001","instance":"/v1","status":42...
# 13389  Quantum Jumping Manifestation | Sarah Scoop Se...
# 13390  What Happens During a Quantum Jump? | Georgia ...
#
# [13391 rows x 5 columns]

# %%
import openai
import time
import re
import pandas as pd

openai.api_key = "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"

# %%
def get_completion(prompt, model="gpt-4"):
    try:
        messages = [{"role": "user", "content": prompt}]
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            temperature=0.2,
        )
        return response.choices[0].message["content"]
    except Exception as e:
        print(f"Error in API call: {e}")
        return None

# %%
#use scraped dataframe (from discord 8/27) and filter out the following:

preprocess_df = pd.read_csv("content_data.csv")
#remove yt videos
preprocess_df = preprocess_df[~preprocess_df['Domain'].str.contains('youtube')]
#remove null or empty values
preprocess_df.dropna(subset=["Text"], inplace=True)
#remove entries with less than 25 words
preprocess_df = preprocess_df[preprocess_df["Text"].apply(lambda x: len(x.split()) >= 25)]

# %%
#export to csv -> preprocess.csv
preprocess_df.to_csv("preprocess.csv", index=False)

# %%
preprocess_df = pd.read_csv("preprocess.csv")

# %%
def getPartsOfText(content):
    x = content[0:50]
    y = content[int(len(content)/2)-150:int(len(content)/2)+150]
    z = content[-50:] 
    return x, y, z

def getGPTval(text, domain):
    x, y, z = getPartsOfText(text)
    website_content = f"""
    First 50 words of content: 
    {x}
    Middle 300 words of content:
    {y}
    Last 50 words of content:
    {z}
    """
    domain_name = domain

    prompt1 = f"""
    Your task is to analyze the complexity of a website's content and assign it a score. You are given snippets of the site's content encapsulated within triple backticks: ```{website_content}```. The score should reflect both the technical difficulty and intricacy of the subject matter presented on the website, with focus on its domain {domain_name}. 

    For assessment, utilize provided representative samples - initial 50 words, 300 words plucked from the middle, and the concluding 50 words.

    While ascertaining the complexity score, weigh factors such as:
    - the degree of technical jargon used,
    - the depth of the technical concepts discussed,
    - complexity of the topic, 
    - the target readership of the webpage.

    A comprehensive explanation of how these factors contribute to the final score needs to be presented.

    The complexity score assigned must be a floating-point number restrained to three decimal places at most. Organize your response in this format:

    Explanation: [Detailed analysis leading to the calculated score]

    Complexity Score: [Decimal number up to three places]

    Remember, although you don't have complete access to the entire webpage content, ensure that all evaluations and scoring rely solely on the provided sampled sections.

    Ultimately, strive for accuracy by ensuring the computed complexity score truly mirrors not just the sophistication but also the technical difficulty with consideration of the domain information.
    """
    prompt2 = f"""
    Your task is to analyze the complexity of a website's content and assign it a score. You are given the site's content encapsulated within triple backticks: ```{website_content}```. The score should reflect both the technical difficulty and intricacy of the subject matter presented on the website, with focus on its domain {domain_name}. 

    For assessment, utilize provided sample.

    While ascertaining the complexity score, weigh factors such as:
    - the degree of technical jargon used,
    - the depth of the technical concepts discussed,
    - complexity of the topic, 
    - the target readership of the webpage.

    A comprehensive explanation of how these factors contribute to the final score needs to be presented.

    The complexity score assigned must be a floating-point number restrained to three decimal places at most. Organize your response in this format:

    Explanation: [Detailed analysis leading to the calculated score]

    Complexity Score: [Decimal number up to three places]

    Ultimately, strive for accuracy by ensuring the computed complexity score truly mirrors not just the sophistication but also the technical difficulty with consideration of the domain information.
    """
    if len(text) > 400:
        prompt = prompt1
    else:
        prompt = prompt2
    response = get_completion(prompt)
    result = re.search(r"Complexity Score: (\d+\.\d+)", response)
    if result:
        return float(result.group(1))
    else:
        return 0.00


for count, item in enumerate(preprocess_df["Text"]):
    gpt_val = getGPTval(item, preprocess_df["Domain"][count])
    if gpt_val is not None:
        preprocess_df.loc[count, "GPTeval"] = gpt_val
    else:
        print(f"Skipping row {count} due to API error.")
        
    if count % 100 == 5 and count != 0:
        preprocess_df.to_csv(f"testpreprocess{count}.csv", index=False)
    
    # Introduce a delay to avoid hitting rate limits
    time.sleep(0.6) 

preprocess_df.to_csv("finalpreprocess.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 78
#      74         return 0.00
#      77 for count, item in enumerate(preprocess_df["Text"]):
# ---> 78     gpt_val = getGPTval(item, preprocess_df["Domain"][count])
#      79     if gpt_val is not None:
#      80         preprocess_df.loc[count, "GPTeval"] = gpt_val
#
# Cell In[10], line 69, in getGPTval(text, domain)
#      67 else:
#      68     prompt = prompt2
# ---> 69 response = get_completion(prompt)
#      70 result = re.search(r"Complexity Score: (\d+\.\d+)", response)
#      71 if result:
#
# Cell In[9], line 4, in get_completion(prompt, model)
#       2 try:
#       3     messages = [{"role": "user", "content": prompt}]
# ----> 4     response = openai.ChatCompletion.create(
#       5         model=model,
#       6         messages=messages,
#       7         temperature=0.2,
#       8     )
#       9     return response.choices[0].message["content"]
#      10 except Exception as e:
#
# File c:\Users\zwill\anaconda3\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\zwill\anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\zwill\anaconda3\lib\site-packages\openai\api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File c:\Users\zwill\anaconda3\lib\site-packages\openai\api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#     527     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File c:\Users\zwill\anaconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\zwill\anaconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\zwill\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\zwill\anaconda3\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\zwill\anaconda3\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\zwill\anaconda3\lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\zwill\anaconda3\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File c:\Users\zwill\anaconda3\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File c:\Users\zwill\anaconda3\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File c:\Users\zwill\anaconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File c:\Users\zwill\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\zwill\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
preprocess_df.to_csv("finalpreprocess.csv", index=False)

# %%
def getPartsOfText(content):
    words = content.split()  # Splitting the content into words
    
    # First 50 words
    x = " ".join(words[:50])
    
    # Middle 300 words
    middle_index = len(words) // 2  # Integer division to get middle index
    y_start = max(0, middle_index - 150)  # Ensure index is not negative
    y_end = middle_index + 150
    y = " ".join(words[y_start:y_end])
    
    # Last 50 words
    z = " ".join(words[-50:])
    
    return x, y, z


def getGPTval(text, domain):
    x, y, z = getPartsOfText(text)
    website_content = f"""
    First 50 words of content: 
    {x}
    Middle 300 words of content:
    {y}
    Last 50 words of content:
    {z}
    """
    domain_name = domain
    content_length = len(text.split())
    print(content_length)
    prompt1 = f"""
    As a thorough content analyst, your chief responsibility revolves around conducting an in-depth analysis of the ```{website_content}``` to devise a well-defined complexity score. This score, defined accurately up to three decimal points, should essentially represent the level of understanding one may acquire for a particular topic within the domain of {domain_name}.
    The total length of the website is given to be {content_length} words.
    For a well-rounded evaluation, scrutinize these three distinct parts of the website content: the introductory 50 words, a 300-word passage from the mid-section, and the final 50 words. Use these segments as a foundation to gauge the overall conceptual complexity of the website's material.

    During your evaluation, factor in these aspects:
    - The frequency and complexity of specialized terminologies.
    - The sophistication and profundity of conveyed technical notions.
    - The cognitive requirement essential to grasp the subject matter.
    - The length of the website content, indicating the scope of the content.
    - The projected target audience of the website.

    Offer a precise, yet comprehensive explanation of how these components shape your final complexity score. 

    Follow this presentation template for your analysis:

    Rationale: [Provide an extensive justification behind your derived complexity score]

    Complexity Score: [Present the final numerical score with precision up to three decimal digits]

    Take note that although your analysis necessitates only a fraction of the entire content, the evaluation must be grounded solely on these provided segments. Your ultimate aim is to generate a compelling complexity score that demonstrates the intricacy and cognitive demand needed to understand the content, while contemplating the specific characteristics of the subject domain.
    """
    prompt2 = f"""
    Your task is to analyze the complexity of a website's content and assign it a score. You are given the site's content encapsulated within triple backticks: ```{website_content}```. The score should reflect both the technical difficulty and intricacy of the subject matter presented on the website, with focus on its domain {domain_name}. 

    For assessment, utilize provided sample.

    While ascertaining the complexity score, weigh factors such as:
    - the degree of technical jargon used,
    - the depth of the technical concepts discussed,
    - complexity of the topic, 
    - the target readership of the webpage.

    A comprehensive explanation of how these factors contribute to the final score needs to be presented.

    The complexity score assigned must be a floating-point number restrained to three decimal places at most. Organize your response in this format:

    Explanation: [Detailed analysis leading to the calculated score]

    Complexity Score: [Decimal number up to three places]

    Ultimately, strive for accuracy by ensuring the computed complexity score truly mirrors not just the sophistication but also the technical difficulty with consideration of the domain information.
    """
    if content_length > 400:
        prompt = prompt1
        print("using prompt1")
    else:
        prompt = prompt2
        print("using prompt2")
    response = get_completion(prompt)
    print(response)

getGPTval(preprocess_df["Text"][4504], preprocess_df["Domain"][4504])
# Out:
# 429
# using prompt1
# Rationale:
#
# The content provided is highly technical and specialized, indicating a high level of complexity. The frequency of specialized terminologies such as "autonomous vehicles", "dsrc-based ivc-enabled", "Platooning Systems", "National Motor Vehicle Crash Causation Survey", and "Life Cycle Assessment of Connected and Automated Vehicles" is high. These terms are not common knowledge and require a certain level of understanding in the field of autonomous vehicles and related technologies to comprehend.
#
# The sophistication and profundity of conveyed technical notions are also high. The content discusses advanced concepts such as autonomous vehicle technology, its impacts, and related legal and policy considerations. Understanding these concepts requires a deep understanding of the subject matter.
#
# The cognitive requirement essential to grasp the subject matter is high. The reader would need to have a background in autonomous vehicle technology, policy, and law to fully understand the content.
#
# The length of the website content, at 429 words, is relatively short. However, the density of technical terms and concepts within this short length adds to the complexity.
#
# The projected target audience of the website is likely to be professionals or researchers in the field of autonomous vehicles or related fields. This is indicated by the use of technical jargon and references to academic studies and reports.
#
# Complexity Score:
#
# Considering all these factors, I would assign a complexity score of 8.567. This score reflects the high level of understanding required to comprehend the content, the frequency and complexity of specialized terminologies, the sophistication of conveyed technical notions, the cognitive requirement, the length of the content, and the projected target audience.

# %%
preprocess_df["URL"][4501]
# Out:
# 'https://ackodrive.com/car-guide/self-driving-cars/'

# %%
some_t = "The guy is not sending things to me"
len(some_t.split())
# Out:
# 8

# %%
"""
NEW PROMPT:
As a website content evaluator, your task is to analyze given snippets from a website and calculate a complexity score with precision up to three decimal places. The score should represent the depth of understanding required to comprehend the content and the prospective learning yield. Your evaluation should be based on the length of the content: {content_length}, and the provided snippets of its content: ```{website_content}```. Ensure that the score encapsulates both the technical complexity and the intricacy of the subject matter related to its domain: {domain_name}.

You have three sections of content to evaluate: the first 50 words, a selection of 300 words from the middle, and the concluding 50 words. 

When calculating the score, consider the following elements:
- The length of the website content, indicating the scope of the content.
- The prevalence of technical jargon.
- The depth of the technical concepts explained.
- The complexity of the subject matter.
- The target audience of the webpage.

Provide an in-depth explanation of how each element contributes to the final score. Format your response as follows:

Explanation: [Your detailed analysis here.]

Complexity Score: [Your decimal score here, accurate to three decimal places.]

Please remember, despite the limited view of the full webpage content, your score should solely be based on the provided snippets. Ensure that your complexity score accurately reflects the complexity and the technical challenge of the content, considering the website's specific domain context.
"""
