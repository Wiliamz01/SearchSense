# %%
import pipelinetest

# %%
demo = pipelinetest.get_result()
# Out:
# Scraping...: 100%|██████████| 1/1 [00:08<00:00,  8.94s/it]
# Search results retrieved successfully
#
#         Title: About COVID-19 symptoms and spread
#         URL: https://www.mass.gov/info-details/about-covid-19-symptoms-and-spread
#         Difficulty: Low Model Score: (0.29890790581703186)
#         --------------------------------------------------------
#
#
#         Title: What is COVID-19?
#         URL: https://www.healthdirect.gov.au/covid-19/about
#         Difficulty: Low Model Score: (0.3470379114151001)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus & COVID-19 Overview
#         URL: https://www.webmd.com/covid/coronavirus
#         Difficulty: Low Model Score: (0.3491816520690918)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus (COVID-19)
#         URL: https://www.hhs.gov/coronavirus/index.html
#         Difficulty: Low Model Score: (0.43418312072753906)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus Disease 2019 (COVID-19)
#         URL: https://www.cdc.gov/coronavirus/2019-ncov/index.html
#         Difficulty: Moderate Model Score: (0.5483076572418213)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus disease 2019 (COVID-19) - Symptoms and ...
#         URL: https://www.mayoclinic.org/diseases-conditions/coronavirus/symptoms-causes/syc-20479963
#         Difficulty: Moderate Model Score: (0.6244035959243774)
#         --------------------------------------------------------
#
#
#         Title: COVID-19 (Coronavirus Disease)
#         URL: https://www.lung.org/lung-health-diseases/lung-disease-lookup/covid-19
#         Difficulty: Moderate Model Score: (0.6681405305862427)
#         --------------------------------------------------------
#
#
#         Title: COVID-19 Test Basics
#         URL: https://www.fda.gov/consumers/consumer-updates/covid-19-test-basics
#         Difficulty: Moderate Model Score: (0.6863389611244202)
#         --------------------------------------------------------
#
#
#         Title: What Is COVID-19? - DC Coronavirus
#         URL: https://coronavirus.dc.gov/page/what-covid-19
#         Difficulty: Moderate Model Score: (0.688068687915802)
#         --------------------------------------------------------
#
#
#         Title: What Is Coronavirus?
#         URL: https://www.hopkinsmedicine.org/health/conditions-and-diseases/coronavirus
#         Difficulty: Moderate Model Score: (0.6923500299453735)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus Disease (COVID-19): Symptoms, Causes & ...
#         URL: https://my.clevelandclinic.org/health/diseases/21214-coronavirus-covid-19
#         Difficulty: Moderate Model Score: (0.6971967816352844)
#         --------------------------------------------------------
#
#
#         Title: About COVID-19
#         URL: https://www.cdc.gov/coronavirus/2019-ncov/your-health/about-covid-19.html
#         Difficulty: Moderate Model Score: (0.6980112791061401)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus (COVID-19): Frequently Asked Questions
#         URL: http://cleaver.house.gov/covid-19-resources/coronavirus-covid-19-frequently-asked-questions
#         Difficulty: Moderate Model Score: (0.7714471220970154)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus Disease 2019 (COVID-19)
#         URL: https://emedicine.medscape.com/article/2500114-overview
#         Difficulty: Moderate Model Score: (0.7843195199966431)
#         --------------------------------------------------------
#
#
#         Title: COVID-19 Definition & Meaning
#         URL: https://www.merriam-webster.com/dictionary/COVID-19
#         Difficulty: Moderate Model Score: (0.7981780171394348)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus Disease (COVID-19)
#         URL: https://www.physio-pedia.com/Coronavirus_Disease_(COVID-19)
#         Difficulty: Moderate Model Score: (0.8182869553565979)
#         --------------------------------------------------------
#
#
#         Title: Coronaviruses: Definition, COVID-19, SARS, MERS
#         URL: https://www.medicalnewstoday.com/articles/256521
#         Difficulty: Moderate Model Score: (0.8254167437553406)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus (COVID-19): Symptoms, Treatment & More
#         URL: https://www.healthline.com/health/coronavirus-covid-19
#         Difficulty: Moderate Model Score: (0.8360665440559387)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus Disease 2019 (COVID-19)
#         URL: https://jamanetwork.com/channels/covid
#         Difficulty: Moderate Model Score: (0.8361759781837463)
#         --------------------------------------------------------
#
#
#         Title: COVID-19 | Cause, Symptoms, Treatment, & Prevention
#         URL: https://www.britannica.com/science/COVID-19
#         Difficulty: Moderate Model Score: (0.8427678942680359)
#         --------------------------------------------------------
#
#
#         Title: What to Know About Coronavirus—COVID-19 Explained
#         URL: https://www.pfizer.com/news/articles/what_to_know_about_coronavirus_covid_19_explained
#         Difficulty: Moderate Model Score: (0.8541678786277771)
#         --------------------------------------------------------
#
#
#         Title: COVID-19 Response and Recovery
#         URL: https://www.state.gov/covid-19-recovery/
#         Difficulty: Moderate Model Score: (0.855153501033783)
#         --------------------------------------------------------
#
#
#         Title: Coronavirus infections - PAHO/WHO
#         URL: https://www.paho.org/en/topics/coronavirus-infections
#         Difficulty: Moderate Model Score: (0.8700168132781982)
#         --------------------------------------------------------
#
#
#         Title: covid-19
#         URL: https://www.yalemedicine.org/conditions/covid-19
#         Difficulty: High Model Score: (0.8838450908660889)
#         --------------------------------------------------------
#
#
#         Title: COVID-19
#         URL: https://en.wikipedia.org/wiki/COVID-19
#         Difficulty: High Model Score: (0.9028322100639343)
#         --------------------------------------------------------
#
#
#         Title: Features, Evaluation, and Treatment of Coronavirus (COVID-19)
#         URL: https://www.ncbi.nlm.nih.gov/books/NBK554776/
#         Difficulty: High Model Score: (0.9190900325775146)
#         --------------------------------------------------------

# %%
from transformers import DistilBertTokenizer

tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
tokenizer.save_pretrained('Desktop/my_tokenizer')
# Out:
# ('Desktop/my_tokenizer/tokenizer_config.json',
#  'Desktop/my_tokenizer/special_tokens_map.json',
#  'Desktop/my_tokenizer/vocab.txt',
#  'Desktop/my_tokenizer/added_tokens.json')
